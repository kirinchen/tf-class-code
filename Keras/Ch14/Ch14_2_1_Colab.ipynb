# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.utils import to_categorical
from keras import regularizers

# 指定亂數種子
seed = 10
np.random.seed(seed)
# 載入資料集
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# 因為是固定範圍, 所以執行正規化, 從 0-255 至 0-1
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255
# One-hot編碼
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
# 定義模型
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding="same",
                 input_shape=X_train.shape[1:], activation="relu",
                 kernel_regularizer=regularizers.l2(0.02),
                 bias_regularizer=regularizers.l2(0.02)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3), padding="same",
                 activation="relu",
                 kernel_regularizer=regularizers.l2(0.02),
                 bias_regularizer=regularizers.l2(0.02)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))
model.summary()   # 顯示模型摘要資訊
# 編譯模型
model.compile(loss="categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
# 訓練模型
history = model.fit(X_train, Y_train, validation_split=0.2, 
                    epochs=34, batch_size=128, verbose=2)
# 評估模型
print("\nTesting ...")
loss, accuracy = model.evaluate(X_test, Y_test)
print("測試資料集的準確度 = {:.2f}".format(accuracy))
# 顯示圖表來分析模型的訓練過程
import matplotlib.pyplot as plt
# 顯示訓練和驗證損失
loss = history.history["loss"]
epochs = range(1, len(loss)+1)
val_loss = history.history["val_loss"]
plt.plot(epochs, loss, "bo-", label="Training Loss")
plt.plot(epochs, val_loss, "ro--", label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# 顯示訓練和驗證準確度
acc = history.history["acc"]
epochs = range(1, len(acc)+1)
val_acc = history.history["val_acc"]
plt.plot(epochs, acc, "bo-", label="Training Acc")
plt.plot(epochs, val_acc, "ro--", label="Validation Acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_45 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,122,186
# Trainable params: 2,122,186
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/34
#  - 7s - loss: 1.9743 - acc: 0.3651 - val_loss: 1.5794 - val_acc: 0.4846
# Epoch 2/34
#  - 4s - loss: 1.5625 - acc: 0.4839 - val_loss: 1.4013 - val_acc: 0.5562
# Epoch 3/34
#  - 4s - loss: 1.4369 - acc: 0.5301 - val_loss: 1.3234 - val_acc: 0.5821
# Epoch 4/34
#  - 4s - loss: 1.3658 - acc: 0.5562 - val_loss: 1.2727 - val_acc: 0.6024
# Epoch 5/34
#  - 4s - loss: 1.3040 - acc: 0.5782 - val_loss: 1.2421 - val_acc: 0.6139
# Epoch 6/34
#  - 4s - loss: 1.2613 - acc: 0.5942 - val_loss: 1.1727 - val_acc: 0.6387
# Epoch 7/34
#  - 4s - loss: 1.2275 - acc: 0.6129 - val_loss: 1.1551 - val_acc: 0.6393
# Epoch 8/34
#  - 4s - loss: 1.1826 - acc: 0.6250 - val_loss: 1.1162 - val_acc: 0.6519
# Epoch 9/34
#  - 4s - loss: 1.1590 - acc: 0.6348 - val_loss: 1.0978 - val_acc: 0.6631
# Epoch 10/34
#  - 4s - loss: 1.1416 - acc: 0.6409 - val_loss: 1.0876 - val_acc: 0.6651
# Epoch 11/34
#  - 4s - loss: 1.1193 - acc: 0.6483 - val_loss: 1.0768 - val_acc: 0.6684
# Epoch 12/34
#  - 4s - loss: 1.0935 - acc: 0.6598 - val_loss: 1.0264 - val_acc: 0.6895
# Epoch 13/34
#  - 4s - loss: 1.0816 - acc: 0.6637 - val_loss: 1.0229 - val_acc: 0.6921
# Epoch 14/34
#  - 4s - loss: 1.0618 - acc: 0.6702 - val_loss: 1.0181 - val_acc: 0.6858
# Epoch 15/34
#  - 4s - loss: 1.0537 - acc: 0.6734 - val_loss: 1.0201 - val_acc: 0.6945
# Epoch 16/34
#  - 4s - loss: 1.0334 - acc: 0.6792 - val_loss: 1.0011 - val_acc: 0.7013
# Epoch 17/34
#  - 4s - loss: 1.0185 - acc: 0.6870 - val_loss: 1.0155 - val_acc: 0.6940
# Epoch 18/34
#  - 4s - loss: 1.0087 - acc: 0.6918 - val_loss: 1.0040 - val_acc: 0.6977
# Epoch 19/34
#  - 4s - loss: 0.9973 - acc: 0.6932 - val_loss: 0.9904 - val_acc: 0.7029
# Epoch 20/34
#  - 4s - loss: 0.9949 - acc: 0.6967 - val_loss: 0.9797 - val_acc: 0.7063
# Epoch 21/34
#  - 4s - loss: 0.9803 - acc: 0.6988 - val_loss: 0.9650 - val_acc: 0.7112
# Epoch 22/34
#  - 4s - loss: 0.9604 - acc: 0.7073 - val_loss: 0.9826 - val_acc: 0.7028
# Epoch 23/34
#  - 4s - loss: 0.9435 - acc: 0.7137 - val_loss: 0.9704 - val_acc: 0.7106
# Epoch 24/34
#  - 4s - loss: 0.9375 - acc: 0.7161 - val_loss: 0.9723 - val_acc: 0.7106
# Epoch 25/34
#  - 4s - loss: 0.9297 - acc: 0.7199 - val_loss: 0.9545 - val_acc: 0.7183
# Epoch 26/34
#  - 4s - loss: 0.9200 - acc: 0.7222 - val_loss: 0.9291 - val_acc: 0.7248
# Epoch 27/34
#  - 4s - loss: 0.9064 - acc: 0.7264 - val_loss: 0.9778 - val_acc: 0.7078
# Epoch 28/34
#  - 4s - loss: 0.9055 - acc: 0.7272 - val_loss: 0.9429 - val_acc: 0.7194
# Epoch 29/34
#  - 4s - loss: 0.8889 - acc: 0.7333 - val_loss: 0.9353 - val_acc: 0.7275
# Epoch 30/34
#  - 4s - loss: 0.8849 - acc: 0.7341 - val_loss: 0.9410 - val_acc: 0.7207
# Epoch 31/34
#  - 4s - loss: 0.8795 - acc: 0.7394 - val_loss: 0.9356 - val_acc: 0.7232
# Epoch 32/34
#  - 4s - loss: 0.8702 - acc: 0.7419 - val_loss: 0.9127 - val_acc: 0.7344
# Epoch 33/34
#  - 4s - loss: 0.8590 - acc: 0.7454 - val_loss: 0.9792 - val_acc: 0.7143
# Epoch 34/34
#  - 4s - loss: 0.8592 - acc: 0.7453 - val_loss: 0.9232 - val_acc: 0.7279
#
# Testing ...
# 10000/10000 [==============================] - 1s 76us/step
# 測試資料集的準確度 = 0.73
