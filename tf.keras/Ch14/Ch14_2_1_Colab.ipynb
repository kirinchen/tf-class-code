# %%
# %tensorflow_version 2.x
import tensorflow
print(tensorflow.__version__)

import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

# 指定亂數種子
seed = 10
np.random.seed(seed)
# 載入資料集
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# 因為是固定範圍, 所以執行正規化, 從 0-255 至 0-1
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255
# One-hot編碼
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
# 定義模型
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding="same",
                 input_shape=X_train.shape[1:], activation="relu",
                 kernel_regularizer=regularizers.l2(0.02),
                 bias_regularizer=regularizers.l2(0.02)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3), padding="same",
                 activation="relu",
                 kernel_regularizer=regularizers.l2(0.02),
                 bias_regularizer=regularizers.l2(0.02)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))
model.summary()   # 顯示模型摘要資訊
# 編譯模型
model.compile(loss="categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
# 訓練模型
history = model.fit(X_train, Y_train, validation_split=0.2, 
                    epochs=34, batch_size=128, verbose=2)
# 評估模型
print("\nTesting ...")
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print("測試資料集的準確度 = {:.2f}".format(accuracy))
# 顯示圖表來分析模型的訓練過程
import matplotlib.pyplot as plt
# 顯示訓練和驗證損失
loss = history.history["loss"]
epochs = range(1, len(loss)+1)
val_loss = history.history["val_loss"]
plt.plot(epochs, loss, "bo-", label="Training Loss")
plt.plot(epochs, val_loss, "ro--", label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# 顯示訓練和驗證準確度
acc = history.history["accuracy"]
epochs = range(1, len(acc)+1)
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo-", label="Training Acc")
plt.plot(epochs, val_acc, "ro--", label="Validation Acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# TensorFlow 2.x selected.
# 2.0.0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,122,186
# Trainable params: 2,122,186
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/34
# 40000/40000 - 10s - loss: 1.9998 - accuracy: 0.3596 - val_loss: 1.6064 - val_accuracy: 0.4836
# Epoch 2/34
# 40000/40000 - 5s - loss: 1.5806 - accuracy: 0.4756 - val_loss: 1.4600 - val_accuracy: 0.5323
# Epoch 3/34
# 40000/40000 - 5s - loss: 1.4625 - accuracy: 0.5167 - val_loss: 1.3998 - val_accuracy: 0.5502
# Epoch 4/34
# 40000/40000 - 5s - loss: 1.4000 - accuracy: 0.5418 - val_loss: 1.3179 - val_accuracy: 0.5819
# Epoch 5/34
# 40000/40000 - 5s - loss: 1.3376 - accuracy: 0.5662 - val_loss: 1.2656 - val_accuracy: 0.5996
# Epoch 6/34
# 40000/40000 - 5s - loss: 1.2973 - accuracy: 0.5808 - val_loss: 1.1973 - val_accuracy: 0.6245
# Epoch 7/34
# 40000/40000 - 5s - loss: 1.2534 - accuracy: 0.5993 - val_loss: 1.1849 - val_accuracy: 0.6407
# Epoch 8/34
# 40000/40000 - 5s - loss: 1.2215 - accuracy: 0.6093 - val_loss: 1.1308 - val_accuracy: 0.6519
# Epoch 9/34
# 40000/40000 - 5s - loss: 1.1938 - accuracy: 0.6200 - val_loss: 1.1383 - val_accuracy: 0.6449
# Epoch 10/34
# 40000/40000 - 5s - loss: 1.1660 - accuracy: 0.6323 - val_loss: 1.0911 - val_accuracy: 0.6635
# Epoch 11/34
# 40000/40000 - 5s - loss: 1.1412 - accuracy: 0.6406 - val_loss: 1.0622 - val_accuracy: 0.6744
# Epoch 12/34
# 40000/40000 - 5s - loss: 1.1213 - accuracy: 0.6481 - val_loss: 1.0634 - val_accuracy: 0.6717
# Epoch 13/34
# 40000/40000 - 5s - loss: 1.1019 - accuracy: 0.6556 - val_loss: 1.0640 - val_accuracy: 0.6745
# Epoch 14/34
# 40000/40000 - 5s - loss: 1.0758 - accuracy: 0.6624 - val_loss: 1.0494 - val_accuracy: 0.6794
# Epoch 15/34
# 40000/40000 - 5s - loss: 1.0670 - accuracy: 0.6648 - val_loss: 1.0414 - val_accuracy: 0.6752
# Epoch 16/34
# 40000/40000 - 5s - loss: 1.0499 - accuracy: 0.6723 - val_loss: 1.0254 - val_accuracy: 0.6852
# Epoch 17/34
# 40000/40000 - 5s - loss: 1.0338 - accuracy: 0.6801 - val_loss: 1.0060 - val_accuracy: 0.6954
# Epoch 18/34
# 40000/40000 - 5s - loss: 1.0257 - accuracy: 0.6829 - val_loss: 0.9996 - val_accuracy: 0.6947
# Epoch 19/34
# 40000/40000 - 5s - loss: 1.0100 - accuracy: 0.6892 - val_loss: 0.9782 - val_accuracy: 0.7064
# Epoch 20/34
# 40000/40000 - 5s - loss: 0.9958 - accuracy: 0.6939 - val_loss: 1.0023 - val_accuracy: 0.7007
# Epoch 21/34
# 40000/40000 - 5s - loss: 0.9837 - accuracy: 0.6992 - val_loss: 0.9703 - val_accuracy: 0.7039
# Epoch 22/34
# 40000/40000 - 5s - loss: 0.9725 - accuracy: 0.7019 - val_loss: 0.9657 - val_accuracy: 0.7144
# Epoch 23/34
# 40000/40000 - 5s - loss: 0.9576 - accuracy: 0.7028 - val_loss: 0.9462 - val_accuracy: 0.7168
# Epoch 24/34
# 40000/40000 - 5s - loss: 0.9523 - accuracy: 0.7080 - val_loss: 0.9340 - val_accuracy: 0.7206
# Epoch 25/34
# 40000/40000 - 5s - loss: 0.9408 - accuracy: 0.7132 - val_loss: 0.9727 - val_accuracy: 0.7076
# Epoch 26/34
# 40000/40000 - 5s - loss: 0.9323 - accuracy: 0.7182 - val_loss: 0.9729 - val_accuracy: 0.7087
# Epoch 27/34
# 40000/40000 - 5s - loss: 0.9192 - accuracy: 0.7210 - val_loss: 0.9684 - val_accuracy: 0.7141
# Epoch 28/34
# 40000/40000 - 5s - loss: 0.9098 - accuracy: 0.7247 - val_loss: 0.9342 - val_accuracy: 0.7222
# Epoch 29/34
# 40000/40000 - 5s - loss: 0.9031 - accuracy: 0.7263 - val_loss: 0.9455 - val_accuracy: 0.7195
# Epoch 30/34
# 40000/40000 - 5s - loss: 0.8970 - accuracy: 0.7289 - val_loss: 0.9271 - val_accuracy: 0.7278
# Epoch 31/34
# 40000/40000 - 5s - loss: 0.8898 - accuracy: 0.7326 - val_loss: 0.9514 - val_accuracy: 0.7169
# Epoch 32/34
# 40000/40000 - 5s - loss: 0.8773 - accuracy: 0.7355 - val_loss: 0.9134 - val_accuracy: 0.7331
# Epoch 33/34
# 40000/40000 - 5s - loss: 0.8657 - accuracy: 0.7423 - val_loss: 0.9157 - val_accuracy: 0.7303
# Epoch 34/34
# 40000/40000 - 5s - loss: 0.8551 - accuracy: 0.7426 - val_loss: 0.9260 - val_accuracy: 0.7258
#
# Testing ...
# 測試資料集的準確度 = 0.72
