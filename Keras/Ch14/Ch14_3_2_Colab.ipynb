# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.utils import to_categorical
from keras import optimizers

# 指定亂數種子
seed = 10
np.random.seed(seed)
# 載入資料集
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# 因為是固定範圍, 所以執行正規化, 從 0-255 至 0-1
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255
# One-hot編碼
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
# 定義模型
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding="same",
                 input_shape=X_train.shape[1:], activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3), padding="same",
                 activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))
model.summary()   # 顯示模型摘要資訊
# 編譯模型
opt_sgd = optimizers.SGD(lr=0.05,decay=1e-6, momentum=.09)
model.compile(loss="categorical_crossentropy", optimizer=opt_sgd,
              metrics=["accuracy"])
# 訓練模型
history = model.fit(X_train, Y_train, validation_split=0.2, 
                    epochs=40, batch_size=128, verbose=2)
# 評估模型
print("\nTesting ...")
loss, accuracy = model.evaluate(X_test, Y_test)
print("測試資料集的準確度 = {:.2f}".format(accuracy))
# 顯示圖表來分析模型的訓練過程
import matplotlib.pyplot as plt
# 顯示訓練和驗證損失
loss = history.history["loss"]
epochs = range(1, len(loss)+1)
val_loss = history.history["val_loss"]
plt.plot(epochs, loss, "bo-", label="Training Loss")
plt.plot(epochs, val_loss, "ro--", label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# 顯示訓練和驗證準確度
acc = history.history["acc"]
epochs = range(1, len(acc)+1)
val_acc = history.history["val_acc"]
plt.plot(epochs, acc, "bo-", label="Training Acc")
plt.plot(epochs, val_acc, "ro--", label="Validation Acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,122,186
# Trainable params: 2,122,186
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/40
#  - 4s - loss: 2.0554 - acc: 0.2477 - val_loss: 2.1938 - val_acc: 0.2334
# Epoch 2/40
#  - 3s - loss: 1.7467 - acc: 0.3758 - val_loss: 1.5524 - val_acc: 0.4507
# Epoch 3/40
#  - 3s - loss: 1.5616 - acc: 0.4396 - val_loss: 1.5552 - val_acc: 0.4353
# Epoch 4/40
#  - 3s - loss: 1.4559 - acc: 0.4748 - val_loss: 1.3419 - val_acc: 0.5282
# Epoch 5/40
#  - 3s - loss: 1.3790 - acc: 0.5027 - val_loss: 1.3239 - val_acc: 0.5462
# Epoch 6/40
#  - 3s - loss: 1.3170 - acc: 0.5269 - val_loss: 1.2343 - val_acc: 0.5648
# Epoch 7/40
#  - 3s - loss: 1.2688 - acc: 0.5477 - val_loss: 1.1806 - val_acc: 0.5847
# Epoch 8/40
#  - 3s - loss: 1.2233 - acc: 0.5652 - val_loss: 1.1697 - val_acc: 0.5907
# Epoch 9/40
#  - 3s - loss: 1.1779 - acc: 0.5802 - val_loss: 1.0961 - val_acc: 0.6227
# Epoch 10/40
#  - 3s - loss: 1.1448 - acc: 0.5927 - val_loss: 1.0675 - val_acc: 0.6289
# Epoch 11/40
#  - 3s - loss: 1.1145 - acc: 0.6031 - val_loss: 1.0443 - val_acc: 0.6328
# Epoch 12/40
#  - 3s - loss: 1.0805 - acc: 0.6152 - val_loss: 1.0218 - val_acc: 0.6466
# Epoch 13/40
#  - 3s - loss: 1.0516 - acc: 0.6273 - val_loss: 0.9835 - val_acc: 0.6542
# Epoch 14/40
#  - 3s - loss: 1.0246 - acc: 0.6384 - val_loss: 0.9859 - val_acc: 0.6556
# Epoch 15/40
#  - 3s - loss: 1.0033 - acc: 0.6438 - val_loss: 0.9526 - val_acc: 0.6674
# Epoch 16/40
#  - 3s - loss: 0.9735 - acc: 0.6553 - val_loss: 0.9367 - val_acc: 0.6750
# Epoch 17/40
#  - 3s - loss: 0.9498 - acc: 0.6630 - val_loss: 0.9161 - val_acc: 0.6853
# Epoch 18/40
#  - 3s - loss: 0.9331 - acc: 0.6706 - val_loss: 0.9033 - val_acc: 0.6843
# Epoch 19/40
#  - 3s - loss: 0.9106 - acc: 0.6759 - val_loss: 0.9547 - val_acc: 0.6656
# Epoch 20/40
#  - 3s - loss: 0.8935 - acc: 0.6817 - val_loss: 0.8807 - val_acc: 0.6902
# Epoch 21/40
#  - 3s - loss: 0.8738 - acc: 0.6901 - val_loss: 0.8818 - val_acc: 0.6948
# Epoch 22/40
#  - 3s - loss: 0.8535 - acc: 0.6982 - val_loss: 0.9454 - val_acc: 0.6742
# Epoch 23/40
#  - 3s - loss: 0.8332 - acc: 0.7059 - val_loss: 0.9369 - val_acc: 0.6700
# Epoch 24/40
#  - 3s - loss: 0.8177 - acc: 0.7114 - val_loss: 0.8404 - val_acc: 0.7073
# Epoch 25/40
#  - 3s - loss: 0.8019 - acc: 0.7188 - val_loss: 0.8502 - val_acc: 0.7015
# Epoch 26/40
#  - 3s - loss: 0.7842 - acc: 0.7217 - val_loss: 0.8536 - val_acc: 0.7016
# Epoch 27/40
#  - 3s - loss: 0.7715 - acc: 0.7254 - val_loss: 0.8258 - val_acc: 0.7153
# Epoch 28/40
#  - 3s - loss: 0.7514 - acc: 0.7326 - val_loss: 0.8351 - val_acc: 0.7067
# Epoch 29/40
#  - 3s - loss: 0.7372 - acc: 0.7386 - val_loss: 0.8206 - val_acc: 0.7168
# Epoch 30/40
#  - 3s - loss: 0.7196 - acc: 0.7444 - val_loss: 0.7979 - val_acc: 0.7216
# Epoch 31/40
#  - 3s - loss: 0.7041 - acc: 0.7479 - val_loss: 0.7944 - val_acc: 0.7219
# Epoch 32/40
#  - 3s - loss: 0.6925 - acc: 0.7538 - val_loss: 0.8002 - val_acc: 0.7255
# Epoch 33/40
#  - 3s - loss: 0.6797 - acc: 0.7568 - val_loss: 0.8050 - val_acc: 0.7221
# Epoch 34/40
#  - 3s - loss: 0.6584 - acc: 0.7669 - val_loss: 0.7874 - val_acc: 0.7268
# Epoch 35/40
#  - 3s - loss: 0.6496 - acc: 0.7695 - val_loss: 0.7773 - val_acc: 0.7325
# Epoch 36/40
#  - 3s - loss: 0.6299 - acc: 0.7751 - val_loss: 0.8456 - val_acc: 0.7088
# Epoch 37/40
#  - 3s - loss: 0.6217 - acc: 0.7785 - val_loss: 0.7898 - val_acc: 0.7304
# Epoch 38/40
#  - 3s - loss: 0.6086 - acc: 0.7818 - val_loss: 0.7623 - val_acc: 0.7387
# Epoch 39/40
#  - 3s - loss: 0.5921 - acc: 0.7880 - val_loss: 0.7621 - val_acc: 0.7393
# Epoch 40/40
#  - 3s - loss: 0.5808 - acc: 0.7929 - val_loss: 0.7654 - val_acc: 0.7376
#
# Testing ...
# 10000/10000 [==============================] - 1s 61us/step
# 測試資料集的準確度 = 0.73
