# %%
# %tensorflow_version 2.x
import tensorflow
print(tensorflow.__version__)

import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers

# 指定亂數種子
seed = 10
np.random.seed(seed)
# 載入資料集
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# 因為是固定範圍, 所以執行正規化, 從 0-255 至 0-1
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255
# One-hot編碼
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
# 定義模型
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding="same",
                 input_shape=X_train.shape[1:], activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3), padding="same",
                 activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))
model.summary()   # 顯示模型摘要資訊
# 編譯模型
opt_sgd = optimizers.SGD(lr=0.05,decay=1e-6, momentum=.09)
model.compile(loss="categorical_crossentropy", optimizer=opt_sgd,
              metrics=["accuracy"])
# 訓練模型
history = model.fit(X_train, Y_train, validation_split=0.2, 
                    epochs=40, batch_size=128, verbose=2)
# 評估模型
print("\nTesting ...")
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print("測試資料集的準確度 = {:.2f}".format(accuracy))
# 顯示圖表來分析模型的訓練過程
import matplotlib.pyplot as plt
# 顯示訓練和驗證損失
loss = history.history["loss"]
epochs = range(1, len(loss)+1)
val_loss = history.history["val_loss"]
plt.plot(epochs, loss, "bo-", label="Training Loss")
plt.plot(epochs, val_loss, "ro--", label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# 顯示訓練和驗證準確度
acc = history.history["accuracy"]
epochs = range(1, len(acc)+1)
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo-", label="Training Acc")
plt.plot(epochs, val_acc, "ro--", label="Validation Acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# TensorFlow 2.x selected.
# 2.0.0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,122,186
# Trainable params: 2,122,186
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/40
# 40000/40000 - 10s - loss: 2.0701 - accuracy: 0.2442 - val_loss: 1.8628 - val_accuracy: 0.3454
# Epoch 2/40
# 40000/40000 - 5s - loss: 1.7811 - accuracy: 0.3626 - val_loss: 1.7581 - val_accuracy: 0.3738
# Epoch 3/40
# 40000/40000 - 5s - loss: 1.6072 - accuracy: 0.4211 - val_loss: 1.5397 - val_accuracy: 0.4546
# Epoch 4/40
# 40000/40000 - 5s - loss: 1.4977 - accuracy: 0.4653 - val_loss: 1.3921 - val_accuracy: 0.5007
# Epoch 5/40
# 40000/40000 - 5s - loss: 1.4163 - accuracy: 0.4949 - val_loss: 1.3772 - val_accuracy: 0.5169
# Epoch 6/40
# 40000/40000 - 5s - loss: 1.3568 - accuracy: 0.5147 - val_loss: 1.2697 - val_accuracy: 0.5488
# Epoch 7/40
# 40000/40000 - 5s - loss: 1.3087 - accuracy: 0.5318 - val_loss: 1.2697 - val_accuracy: 0.5570
# Epoch 8/40
# 40000/40000 - 5s - loss: 1.2568 - accuracy: 0.5541 - val_loss: 1.2205 - val_accuracy: 0.5777
# Epoch 9/40
# 40000/40000 - 5s - loss: 1.2227 - accuracy: 0.5638 - val_loss: 1.1857 - val_accuracy: 0.5772
# Epoch 10/40
# 40000/40000 - 5s - loss: 1.1844 - accuracy: 0.5793 - val_loss: 1.1657 - val_accuracy: 0.5888
# Epoch 11/40
# 40000/40000 - 5s - loss: 1.1467 - accuracy: 0.5912 - val_loss: 1.0983 - val_accuracy: 0.6177
# Epoch 12/40
# 40000/40000 - 5s - loss: 1.1129 - accuracy: 0.6022 - val_loss: 1.0922 - val_accuracy: 0.6132
# Epoch 13/40
# 40000/40000 - 5s - loss: 1.0868 - accuracy: 0.6127 - val_loss: 1.0565 - val_accuracy: 0.6309
# Epoch 14/40
# 40000/40000 - 4s - loss: 1.0578 - accuracy: 0.6244 - val_loss: 1.0380 - val_accuracy: 0.6371
# Epoch 15/40
# 40000/40000 - 5s - loss: 1.0351 - accuracy: 0.6332 - val_loss: 1.0848 - val_accuracy: 0.6267
# Epoch 16/40
# 40000/40000 - 5s - loss: 1.0056 - accuracy: 0.6424 - val_loss: 0.9748 - val_accuracy: 0.6550
# Epoch 17/40
# 40000/40000 - 5s - loss: 0.9832 - accuracy: 0.6517 - val_loss: 0.9923 - val_accuracy: 0.6493
# Epoch 18/40
# 40000/40000 - 5s - loss: 0.9648 - accuracy: 0.6579 - val_loss: 0.9355 - val_accuracy: 0.6739
# Epoch 19/40
# 40000/40000 - 4s - loss: 0.9418 - accuracy: 0.6666 - val_loss: 0.9152 - val_accuracy: 0.6794
# Epoch 20/40
# 40000/40000 - 5s - loss: 0.9208 - accuracy: 0.6711 - val_loss: 0.9167 - val_accuracy: 0.6848
# Epoch 21/40
# 40000/40000 - 5s - loss: 0.8929 - accuracy: 0.6844 - val_loss: 0.9778 - val_accuracy: 0.6571
# Epoch 22/40
# 40000/40000 - 5s - loss: 0.8721 - accuracy: 0.6924 - val_loss: 0.8976 - val_accuracy: 0.6849
# Epoch 23/40
# 40000/40000 - 5s - loss: 0.8561 - accuracy: 0.6970 - val_loss: 0.8729 - val_accuracy: 0.6992
# Epoch 24/40
# 40000/40000 - 5s - loss: 0.8350 - accuracy: 0.7051 - val_loss: 0.8436 - val_accuracy: 0.7076
# Epoch 25/40
# 40000/40000 - 5s - loss: 0.8270 - accuracy: 0.7082 - val_loss: 0.9206 - val_accuracy: 0.6806
# Epoch 26/40
# 40000/40000 - 5s - loss: 0.8015 - accuracy: 0.7148 - val_loss: 0.8712 - val_accuracy: 0.6970
# Epoch 27/40
# 40000/40000 - 5s - loss: 0.7884 - accuracy: 0.7177 - val_loss: 0.8372 - val_accuracy: 0.7074
# Epoch 28/40
# 40000/40000 - 5s - loss: 0.7710 - accuracy: 0.7266 - val_loss: 0.8168 - val_accuracy: 0.7131
# Epoch 29/40
# 40000/40000 - 5s - loss: 0.7525 - accuracy: 0.7333 - val_loss: 0.8002 - val_accuracy: 0.7224
# Epoch 30/40
# 40000/40000 - 5s - loss: 0.7384 - accuracy: 0.7389 - val_loss: 0.8336 - val_accuracy: 0.7089
# Epoch 31/40
# 40000/40000 - 5s - loss: 0.7242 - accuracy: 0.7400 - val_loss: 0.7859 - val_accuracy: 0.7271
# Epoch 32/40
# 40000/40000 - 5s - loss: 0.7064 - accuracy: 0.7488 - val_loss: 0.7975 - val_accuracy: 0.7233
# Epoch 33/40
# 40000/40000 - 5s - loss: 0.7028 - accuracy: 0.7507 - val_loss: 0.8116 - val_accuracy: 0.7185
# Epoch 34/40
# 40000/40000 - 5s - loss: 0.6759 - accuracy: 0.7587 - val_loss: 0.8082 - val_accuracy: 0.7226
# Epoch 35/40
# 40000/40000 - 5s - loss: 0.6683 - accuracy: 0.7642 - val_loss: 0.8288 - val_accuracy: 0.7147
# Epoch 36/40
# 40000/40000 - 5s - loss: 0.6527 - accuracy: 0.7698 - val_loss: 0.7991 - val_accuracy: 0.7231
# Epoch 37/40
# 40000/40000 - 5s - loss: 0.6407 - accuracy: 0.7712 - val_loss: 0.7776 - val_accuracy: 0.7290
# Epoch 38/40
# 40000/40000 - 5s - loss: 0.6254 - accuracy: 0.7768 - val_loss: 0.7759 - val_accuracy: 0.7344
# Epoch 39/40
# 40000/40000 - 5s - loss: 0.6162 - accuracy: 0.7792 - val_loss: 0.7615 - val_accuracy: 0.7366
# Epoch 40/40
# 40000/40000 - 5s - loss: 0.5981 - accuracy: 0.7872 - val_loss: 0.7653 - val_accuracy: 0.7372
#
# Testing ...
# 測試資料集的準確度 = 0.73
